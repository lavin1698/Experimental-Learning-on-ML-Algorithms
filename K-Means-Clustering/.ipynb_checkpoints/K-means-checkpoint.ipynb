# %%
#k-means clutering on diabetes dataset

# %%
import numpy as np
import pandas as pd

# %%
#importing csv files
train=pd.read_csv("C:/Users/lavin/Downloads/ML record/pima-indians-diabetes-database/diabetes.csv")

# %%
train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
train.shape
# Out:
# (768, 9)

# %%
#missing data
total = train.isnull().sum().sort_values(ascending=False)
percent = (train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#                           Total  Percent
# Outcome                       0      0.0
# Age                           0      0.0
# DiabetesPedigreeFunction      0      0.0
# BMI                           0      0.0
# Insulin                       0      0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#To fill these Nan values the data distribution needs to be understood
f, axes = plt.subplots(4,2, figsize=(20,20))
sns.distplot(train.Pregnancies, ax=axes[0,0])
sns.distplot(train.Glucose, ax=axes[0,1])
sns.distplot(train.BloodPressure, ax=axes[1,0])
sns.distplot(train.SkinThickness, ax=axes[1,1])
sns.distplot(train.Insulin, ax=axes[2,0])
sns.distplot(train.BMI, ax=axes[2,1])
sns.distplot(train.DiabetesPedigreeFunction, ax=axes[3,0])
sns.distplot(train.Age, ax=axes[3,1])

# %%
sns.countplot(train['Outcome'], label = 'Count')

# %%
plt.figure(figsize = (8,6))
sns.heatmap(train.corr(),
            xticklabels=train.corr().columns.values,
            yticklabels=train.corr().columns.values,
            annot=True,fmt='.2f',linewidths=0.30,
             linecolor='white')
plt.title('Correlation of train data Features', y = 1.05, size=10)
# Out:
# Text(0.5, 1.05, 'Correlation of train data Features')

# %%
#fitting K-means

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2)

# %%
kmeans.fit(train.drop('Outcome',axis=1))
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[  3.7030303 , 141.46060606,  72.78787879,  31.2       ,
#         253.70909091,  34.98545455,   0.59724848,  33.7030303 ],
#        [  3.88391376, 115.26699834,  68.09784411,  17.6185738 ,
#          32.21227197,  31.17363184,   0.43757048,  33.11442786]])

# %%
def converter(cluster):
    if cluster=='Yes':
        return 1
    else:
        return 0

# %%
train['Cluster'] = train['Outcome'].apply(converter)

# %%
train.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Cluster
# 0                     0.627   50        1        0
# 1                     0.351   31        0        0
# 2                     0.672   32        1        0
# 3                     0.167   21        0        0
# 4                     2.288   33        1        0

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(train['Cluster'],kmeans.labels_))
print(classification_report(train['Cluster'],kmeans.labels_))
# Out:
# [[165 603]
#  [  0   0]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.21      0.35       768
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.21       768
#    macro avg       0.50      0.11      0.18       768
# weighted avg       1.00      0.21      0.35       768
# C:\Users\Ayush Shah\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
